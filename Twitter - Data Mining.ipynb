# %%
import tweepy
import nltk

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
pd.options.display.max_columns = 50
pd.options.display.max_rows= 50
pd.options.display.width= 120

# %%
consumer_key = "5Ln59uDjshWmHlP5z4Unm5MHx" # Use your own key. To get a key https://apps.twitter.com/
consumer_secret = "sqvTAlQQ5clD6lQTEBEgGgQnUhbHVoDepFgl2DDQLXpYSSNqv5"

auth = tweepy.OAuthHandler(consumer_key=consumer_key, consumer_secret=consumer_secret)

api = tweepy.API(auth)

# %%
results = api.search(q='Cubs')
results2= api.search(q='Indians')

# %%
len(results)
# Out:
# 15

# %%
def print_tweet(tweet):
    print "@%s - %s (%s)" % (tweet.user.screen_name, tweet.user.name, tweet.created_at)
    print tweet.text

tweet=results[1]
print_tweet(tweet)
# Out:
# @ruiz_magaly - Magaly Ruiz (2016-11-01 11:18:52)
# RT @ESPN_Beisbol: Los Cubs van de nuevo a desafiar a la historia en el juego de eliminación que le podría dar el triunfo en la #smxes… http…

# %%
tweet=results[1]

for param in dir(tweet):
    if not param.startswith("_"):
        print "%s : %s" % (param, eval("tweet." + param))
# Out:
# author : User(follow_request_sent=None, has_extended_profile=False, profile_use_background_image=True, _json={u'follow_request_sent': None, u'has_extended_profile': False, u'profile_use_background_image': True, u'default_profile_image': False, u'id': 327987875, u'profile_background_image_url_https': u'https://abs.twimg.com/images/themes/theme1/bg.png', u'verified': False, u'translator_type': u'none', u'profile_text_color': u'333333', u'profile_image_url_https': u'https://pbs.twimg.com/profile_images/785193515408130048/Vimbyu59_normal.jpg', u'profile_sidebar_fill_color': u'DDEEF6', u'entities': {u'description': {u'urls': []}}, u'followers_count': 269, u'profile_sidebar_border_color': u'C0DEED', u'id_str': u'327987875', u'profile_background_color': u'C0DEED', u'listed_count': 30, u'is_translation_enabled': False, u'utc_offset': None, u'statuses_count': 30579, u'description': u'God first\U0001f64f\nMy religion is LOVE \u2764 PEACE..Spirituality..\nGood Vibes...\u270cAnimal lover...\nLik
# ...

# %%
user=tweet.author

for param in dir(user):
    if not param.startswith("_"):
        print "%s : %s" % (param, eval("user." + param))
# Out:
# contributors_enabled : False
# created_at : 2011-10-07 22:54:05
# default_profile : False
# default_profile_image : False
# description :
# entities : {u'description': {u'urls': []}}
# favourites_count : 3318
# ...

# %%
results = []
for tweet in tweepy.Cursor(api.search, q="Cubs").items(500):
    results.append(tweet)

print len(results)
# Out:
# 500

# %%
def process_results(results):
    id_list = [tweet.id for tweet in results]
    data_set = pd.DataFrame(id_list, columns=["id"])

    # Processing Tweet Data

    data_set["text"] = [tweet.text for tweet in results]
    

    return data_set
data_set = process_results(results)

# %%
DF1 = data_set['text']
DF1[400]
# Out:
# u'RT @DexterFowler: Saw a kid in a Cubs uniform. Told him his costume was sick... asked him who is favorite player is. He said @ARizzo44....c\u2026'

# %%
sources = data_set["source"].value_counts()[:5][::-1]

plt.barh(xrange(len(sources)), sources.values)
plt.yticks(np.arange(len(sources)) + 0.4, sources.index)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-5cf6c271a0ae> in <module>()
# ----> 1 sources = data_set["source"].value_counts()[:5][::-1]
#       2
#       3 plt.barh(xrange(len(sources)), sources.values)
#       4 plt.yticks(np.arange(len(sources)) + 0.4, sources.index)
#       5 plt.show()
#
# C:\Users\hlo\Anaconda2\lib\site-packages\pandas\core\frame.pyc in __getitem__(self, key)
#    1995             return self._getitem_multilevel(key)
#    1996         else:
# -> 1997             return self._getitem_column(key)
#    1998
#    1999     def _getitem_column(self, key):
#
# C:\Users\hlo\Anaconda2\lib\site-packages\pandas\core\frame.pyc in _getitem_column(self, key)
#    2002         # get column
#    2003         if self.columns.is_unique:
# -> 2004             return self._get_item_cache(key)
#    2005
# ...

# %%
results2 = []
for tweet in tweepy.Cursor(api.search, q="Indians").items(500):
    results2.append(tweet)

print len(results2)
# Out:
# 500

# %%
def process_results(results2):
    id_list = [tweet.id for tweet in results2]
    data_set = pd.DataFrame(id_list, columns=["id"])

    # Processing Tweet Data

    data_set["text"] = [tweet.text for tweet in results2]
    

    return data_set
dataset2 = process_results(results2)

# %%
from nltk.twitter import Twitter
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-21-8fcc9e1ad662> in <module>()
#       1
# ----> 2 from nltk.twitter import Twitter
#
# ImportError: cannot import name Twitter

# %%
uniqueWords = list(set(" ".join(data_set2).lower().split(" ")))
count = len(uniqueWords)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-4b66ad388e97> in <module>()
# ----> 1 import graphlab
#
# ImportError: No module named graphlab

# %%
dataset2
# Out:
#                      id                                               text
# 0    793412075460648960  RT @ItssGiless: Indians boutta drop a 3-1 lead...
# 1    793412071299944448  RT @Indians: Good morning, Cleveland. #RallyTo...
# 2    793412065150971908  Indian Teen Arrested In US For Choking 911 Lin...
# 3    793412054090715136  The great failure of the Indians mascot debate...
# 4    793412046649856000  RT @MLBJapan: 今一番流行っているハロウィン衣装 指を負傷した時のトレバー・バウ...
# 5    793412045647511552  @Indians gonna win the World Series here in th...
# 6    793412038060077056  RT @Indians: Good morning, Cleveland. #RallyTo...
# 7    793412037330087937  Indian Teen Arrested In US For Choking 911 Lin...
# 8    793412026366177280  RT @Native_NewsNet: How North Dakota Governmen...
# 9    793412023157534720  RT @Indians: Good morning, Cleveland. #RallyTo...
# 10   793412018900316160  Indian Teen Arrested In US For Choking 911 Lin...
# ...

# %%
dataset3 = dataset2['text']
s = pd.Series([dataset3], name = 'text')

# %%
stwo = s.tolist()

# %%
stwo
# Out:
# [0      RT @ItssGiless: Indians boutta drop a 3-1 lead...
#  1      RT @Indians: Good morning, Cleveland. #RallyTo...
#  2      Indian Teen Arrested In US For Choking 911 Lin...
#  3      The great failure of the Indians mascot debate...
#  4      RT @MLBJapan: 今一番流行っているハロウィン衣装 指を負傷した時のトレバー・バウ...
#  5      @Indians gonna win the World Series here in th...
#  6      RT @Indians: Good morning, Cleveland. #RallyTo...
#  7      Indian Teen Arrested In US For Choking 911 Lin...
#  8      RT @Native_NewsNet: How North Dakota Governmen...
#  9      RT @Indians: Good morning, Cleveland. #RallyTo...
#  10     Indian Teen Arrested In US For Choking 911 Lin...
#  11     RT @Indians: Good morning, Cleveland. #RallyTo...
#  12     Indian Teen Arrested In US For Choking 911 Lin...
#  13            I'm ready to die @Indians \n#RallyTogether
#  14          @izzygeraci @Indians https://t.co/NGo0jUCNXf
#  15     Indian Teen Arrested In US For Choking 911 Lin...
# ...

# %%
dataset2.to_csv('C:\Users\hlo\Desktop\My Websites\df',sep='\t', encoding='utf-8')

# %%
dataset2.to_csv('C:\Users\hlo\Desktop\My Websites\dftwo', sep ='t', encoding='utf-8')

# %%
# Out:
# C:\Users\hlo\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-c867d9299ba4> in <module>()
#       1 for text[1] in stwo:
# ----> 2     print text[1]
#
# C:\Users\hlo\Anaconda2\lib\site-packages\pandas\core\base.pyc in __str__(self)
#      45         if compat.PY3:
#      46             return self.__unicode__()
# ---> 47         return self.__bytes__()
#      48
#      49     def __bytes__(self):
#
# C:\Users\hlo\Anaconda2\lib\site-packages\pandas\core\base.pyc in __bytes__(self)
#      57
#      58         encoding = get_option("display.encoding")
# ...
